# %% [markdown]
# # Data science methodology

# %% [markdown]
# #### In this project, I will demonstrate my understanding of the data science methodology by applying it to a problem.

# %% [markdown]
# ### Problems of email

# %% [markdown]
# SCENARIO:
#
# In this project, I will have to play the role of the client as well as the data scientist.

# %% [markdown]
# CLIENTS PROBLEMS:
#
#    Identifying the important emails and deleting the unnecessary ones.

# %% [markdown]
# QUESTIONS TO BE ANSWERED:
#
#   1. What are the emails which  basically comes under important emails?
#
#   2. Who are the person or organization which  sends us important mails?

# %% [markdown]
# ##### STEPS INVOLVED IN DATA SCIENCE METHODOLOGY

# %% [markdown]
# S![](![image.png](attachment:99f006cb-f01c-4d9c-8535-2f3a6014127c.png)

# %% [markdown]
# *1. Business understanding*
#
# *2. Analytic Approach*
#
# *3. Data Requirements*
#
# *4. Data Collection*
#
# *5. Data Understanding and Preparation*
#
# *6. Modeling and Evaluation*

# %% [markdown]
# #####   BUSINESS UNDERSTANDING:
#
#             Identifying the important emails and deleting the unnecessary ones.

# %% [markdown]
# ##### ANALYTIC APPROACH:
#
#             Listing the emails which are important to us. For example, bank details, personal details, educational mails etc..Here a combination predictive model and descriptive model is used to solve the problem

# %% [markdown]
# ##### DATA REQUIREMENTS:
#
#             we should identify from where the important data is been collected. For example, bank emails comes from the bank. Personal mails comes from our friends and family and other many from the government.

# %% [markdown]
# ##### DATA COLLECTION:
#             The required data can be collected from the various emails in our personal account.

# %% [markdown]
# ##### DATA UNDERSTANDING AND PREPARATION;
#             As we know bank details , educational details are important. but we don't need to consider the scheme, event messages which comes from the bank and universities.

# %% [markdown]
# ##### MODELING AND EVALUTION:
#
#             we have split we folder in such a way that the emails form bank, universities and government will go to important mails but not the schemes introducted by this organization. And all the other unnecessary mails and schemes are kept in unnecessary mails. By this model we can delete the unnecessary mails easily.

# %% [markdown]
# ##### conclusion:
#
#               By this model we can delete the unnecessary mails easily. This model can be deployed so that we can make furthur improvisation or correction.

# %% [markdown]
# ## Author
# *Mohanaprasath*
